# %%
import numpy as np
import pandas as pd

# %%
import pickle

enron_data = pickle.load(open("final_project_dataset_unix.pkl", "rb"))
enron_data["SKILLING JEFFREY K"]
# Out:
# {'salary': 1111258,
#  'to_messages': 3627,
#  'deferral_payments': 'NaN',
#  'total_payments': 8682716,
#  'loan_advances': 'NaN',
#  'bonus': 5600000,
#  'email_address': 'jeff.skilling@enron.com',
#  'restricted_stock_deferred': 'NaN',
#  'deferred_income': 'NaN',
#  'total_stock_value': 26093672,
#  'expenses': 29336,
#  'from_poi_to_this_person': 88,
#  'exercised_stock_options': 19250000,
#  'from_messages': 108,
#  'other': 22122,
#  'from_this_person_to_poi': 30,
#  'poi': True,
#  'long_term_incentive': 1920000,
#  'shared_receipt_with_poi': 2042,
#  'restricted_stock': 6843672,
#  'director_fees': 'NaN'}

# %%
enron_data
# Out:
# {'METTS MARK': {'salary': 365788,
#   'to_messages': 807,
#   'deferral_payments': 'NaN',
#   'total_payments': 1061827,
#   'loan_advances': 'NaN',
#   'bonus': 600000,
#   'email_address': 'mark.metts@enron.com',
#   'restricted_stock_deferred': 'NaN',
#   'deferred_income': 'NaN',
#   'total_stock_value': 585062,
#   'expenses': 94299,
#   'from_poi_to_this_person': 38,
#   'exercised_stock_options': 'NaN',
#   'from_messages': 29,
#   'other': 1740,
#   'from_this_person_to_poi': 1,
#   'poi': False,
#   'long_term_incentive': 'NaN',
#   'shared_receipt_with_poi': 702,
#   'restricted_stock': 585062,
#   'director_fees': 'NaN'},
#  'BAXTER JOHN C': {'salary': 267102,
#   'to_messages': 'NaN',
#   'deferral_payments': 1295738,
#   'total_payments': 5634343,
#   'loan_advances': 'NaN',
#   'bonus': 1200000,
#   'email_address': 'NaN',
#   'restricted_stock_deferred': 'NaN',
#   'deferred_income': -1386055,
#   'total_stock_value': 10623258,
#   'expenses': 11200,
# ...

# %%
# Just a Practice
enron_data["SKILLING JEFFREY K"]
# Out:
# {'salary': 1111258,
#  'to_messages': 3627,
#  'deferral_payments': 'NaN',
#  'total_payments': 8682716,
#  'loan_advances': 'NaN',
#  'bonus': 5600000,
#  'email_address': 'jeff.skilling@enron.com',
#  'restricted_stock_deferred': 'NaN',
#  'deferred_income': 'NaN',
#  'total_stock_value': 26093672,
#  'expenses': 29336,
#  'from_poi_to_this_person': 88,
#  'exercised_stock_options': 19250000,
#  'from_messages': 108,
#  'other': 22122,
#  'from_this_person_to_poi': 30,
#  'poi': True,
#  'long_term_incentive': 1920000,
#  'shared_receipt_with_poi': 2042,
#  'restricted_stock': 6843672,
#  'director_fees': 'NaN'}

# %%
# Just a Practice
enron_data["SKILLING JEFFREY K"]["poi"]
# Out:
# True

# %%
# total count for the person of interenst poi in the available dataset
count = 0
for key, value in enron_data.items():
    if value['poi'] == True:
        count += 1
count
# Out:
# 18

# %%
# total count of stock value for James Prentice
enron_data["PRENTICE JAMES"]["total_stock_value"]
# Out:
# 1095040

# %%
import pandas as pd
import pickle

enron_data = pickle.load(open("final_project_dataset_unix.pkl", "rb"))

df = pd.DataFrame.from_dict(enron_data)
df
# Out:
#                                      METTS MARK BAXTER JOHN C  \
# salary                                   365788        267102
# to_messages                                 807           NaN
# deferral_payments                           NaN       1295738
# total_payments                          1061827       5634343
# loan_advances                               NaN           NaN
# bonus                                    600000       1200000
# email_address              mark.metts@enron.com           NaN
# restricted_stock_deferred                   NaN           NaN
# deferred_income                             NaN      -1386055
# total_stock_value                        585062      10623258
# expenses                                  94299         11200
# from_poi_to_this_person                      38           NaN
# exercised_stock_options                     NaN       6680544
# from_messages                                29           NaN
# ...

# %%
# Just a Practice
df.shape
# Out:
# (21, 146)

# %%
# Just a Practice
len(df.columns)
# Out:
# 146

# %%
# Just a Practice
df = pd.DataFrame.from_dict(enron_data, orient="index")
df
# Out:
#                       salary to_messages deferral_payments total_payments  \
# METTS MARK            365788         807               NaN        1061827
# BAXTER JOHN C         267102         NaN           1295738        5634343
# ELLIOTT STEVEN        170941         NaN               NaN         211725
# CORDES WILLIAM R         NaN         764               NaN            NaN
# HANNON KEVIN P        243293        1045               NaN         288682
# ...                      ...         ...               ...            ...
# GRAMM WENDY L            NaN         NaN               NaN         119292
# CAUSEY RICHARD A      415189        1892               NaN        1868758
# TAYLOR MITCHELL S     265214         533            227449        1092663
# DONAHUE JR JEFFREY M  278601         865               NaN         875760
# GLISAN JR BEN F       274975         873               NaN        1272284
#
#                      loan_advances    bonus              email_address  \
# ...

# %%
# Just a Practice
len(df.columns)
# Out:
# 21

# %%
df.describe()
# Out:
#        salary to_messages deferral_payments total_payments loan_advances  \
# count     146         146               146            146           146
# unique     95          87                40            126             5
# top       NaN         NaN               NaN            NaN           NaN
# freq       51          60               107             21           142
#
#        bonus email_address restricted_stock_deferred deferred_income  \
# count    146           146                       146             146
# unique    42           112                        19              45
# top      NaN           NaN                       NaN             NaN
# freq      64            35                       128              97
#
#        total_stock_value  ... from_poi_to_this_person exercised_stock_options  \
# count                146  ...                     146                     146
# unique               125  ...                      58                     102
# ...

# %%
# Change index column name to name
df = pd.DataFrame.from_dict(enron_data, orient="index")
df.reset_index(level=0, inplace=True)
df.rename(columns={"index": "name"}, inplace=True)
df.head().T
# Out:
#                                               0              1  \
# name                                 METTS MARK  BAXTER JOHN C
# salary                                   365788         267102
# to_messages                                 807            NaN
# deferral_payments                           NaN        1295738
# total_payments                          1061827        5634343
# loan_advances                               NaN            NaN
# bonus                                    600000        1200000
# email_address              mark.metts@enron.com            NaN
# restricted_stock_deferred                   NaN            NaN
# deferred_income                             NaN       -1386055
# total_stock_value                        585062       10623258
# expenses                                  94299          11200
# from_poi_to_this_person                      38            NaN
# exercised_stock_options                     NaN        6680544
# ...

# %%
len(df.columns)
# Out:
# 22

# %%
df.poi.value_counts()
# Out:
# False    128
# True      18
# Name: poi, dtype: int64

# %%
# How many email messages do we have from Colwell Wesley to person of interest
df[df['name'] == 'COLWELL WESLEY'].T
#ans = 11
# Out:
#                                               16
# name                              COLWELL WESLEY
# salary                                    288542
# to_messages                                 1758
# deferral_payments                          27610
# total_payments                           1490344
# loan_advances                                NaN
# bonus                                    1200000
# email_address              wes.colwell@enron.com
# restricted_stock_deferred                    NaN
# deferred_income                          -144062
# total_stock_value                         698242
# expenses                                   16514
# from_poi_to_this_person                      240
# exercised_stock_options                      NaN
# from_messages                                 40
# other                                     101740
# from_this_person_to_poi                       11
# poi                                         True
# ...

# %%
df[df['name'] == 'SKILLING JEFFREY K'].T
# Out:
#                                                 95
# name                            SKILLING JEFFREY K
# salary                                     1111258
# to_messages                                   3627
# deferral_payments                              NaN
# total_payments                             8682716
# loan_advances                                  NaN
# bonus                                      5600000
# email_address              jeff.skilling@enron.com
# restricted_stock_deferred                      NaN
# deferred_income                                NaN
# total_stock_value                         26093672
# expenses                                     29336
# from_poi_to_this_person                         88
# exercised_stock_options                   19250000
# from_messages                                  108
# other                                        22122
# from_this_person_to_poi                         30
# ...

# %%
enron_data["SKILLING JEFFREY K"]
# Out:
# {'salary': 1111258,
#  'to_messages': 3627,
#  'deferral_payments': 'NaN',
#  'total_payments': 8682716,
#  'loan_advances': 'NaN',
#  'bonus': 5600000,
#  'email_address': 'jeff.skilling@enron.com',
#  'restricted_stock_deferred': 'NaN',
#  'deferred_income': 'NaN',
#  'total_stock_value': 26093672,
#  'expenses': 29336,
#  'from_poi_to_this_person': 88,
#  'exercised_stock_options': 19250000,
#  'from_messages': 108,
#  'other': 22122,
#  'from_this_person_to_poi': 30,
#  'poi': True,
#  'long_term_incentive': 1920000,
#  'shared_receipt_with_poi': 2042,
#  'restricted_stock': 6843672,
#  'director_fees': 'NaN'}

# %%
# Research the ENRON Fraud
# Enron CEO during fraud: Jeffrey K Skilling
# Enron Chairman during fraud: Kenneth L Lay
# Enron CFO during fraud: Andrew Fastow

# %%
ken = df[df['name'] == 'LAY KENNETH L'].T
ken
# Out:
#                                               64
# name                               LAY KENNETH L
# salary                                   1072321
# to_messages                                 4273
# deferral_payments                         202911
# total_payments                         103559793
# loan_advances                           81525000
# bonus                                    7000000
# email_address              kenneth.lay@enron.com
# restricted_stock_deferred                    NaN
# deferred_income                          -300000
# total_stock_value                       49110078
# expenses                                   99832
# from_poi_to_this_person                      123
# exercised_stock_options                 34348384
# from_messages                                 36
# other                                   10359729
# from_this_person_to_poi                       16
# poi                                         True
# ...

# %%
df.head(65)
# Out:
#                            name   salary to_messages deferral_payments  \
# 0                    METTS MARK   365788         807               NaN
# 1                 BAXTER JOHN C   267102         NaN           1295738
# 2                ELLIOTT STEVEN   170941         NaN               NaN
# 3              CORDES WILLIAM R      NaN         764               NaN
# 4                HANNON KEVIN P   243293        1045               NaN
# ..                          ...      ...         ...               ...
# 60  SULLIVAN-SHAKLOVITZ COLLEEN   162779         NaN            181993
# 61                 WROBEL BRUCE      NaN         NaN               NaN
# 62               LINDHOLM TOD A   236457         NaN            204075
# 63               MEYER JEROME J      NaN         NaN               NaN
# 64                LAY KENNETH L  1072321        4273            202911
#
#    total_payments loan_advances    bonus             email_address  \
# ...

# %%
# sum = df.at[64, 'salary'] + df.at[64, 'salary']
# sum
df.at[64, 'total_payments']
# Out:
# 103559793

# %%
# Just a Practice
df.shape
# Out:
# (146, 22)

# %%
# Just a Practice
df.describe
# Out:
# <bound method NDFrame.describe of                      name  salary to_messages deferral_payments  \
# 0              METTS MARK  365788         807               NaN
# 1           BAXTER JOHN C  267102         NaN           1295738
# 2          ELLIOTT STEVEN  170941         NaN               NaN
# 3        CORDES WILLIAM R     NaN         764               NaN
# 4          HANNON KEVIN P  243293        1045               NaN
# ..                    ...     ...         ...               ...
# 141         GRAMM WENDY L     NaN         NaN               NaN
# 142      CAUSEY RICHARD A  415189        1892               NaN
# 143     TAYLOR MITCHELL S  265214         533            227449
# 144  DONAHUE JR JEFFREY M  278601         865               NaN
# 145       GLISAN JR BEN F  274975         873               NaN
#
#     total_payments loan_advances    bonus              email_address  \
# 0          1061827           NaN   600000       mark.metts@enron.com
# ...

# %%
# Just a Practice
df.head()
# Out:
#                name  salary to_messages deferral_payments total_payments  \
# 0        METTS MARK  365788         807               NaN        1061827
# 1     BAXTER JOHN C  267102         NaN           1295738        5634343
# 2    ELLIOTT STEVEN  170941         NaN               NaN         211725
# 3  CORDES WILLIAM R     NaN         764               NaN            NaN
# 4    HANNON KEVIN P  243293        1045               NaN         288682
#
#   loan_advances    bonus             email_address restricted_stock_deferred  \
# 0           NaN   600000      mark.metts@enron.com                       NaN
# 1           NaN  1200000                       NaN                       NaN
# 2           NaN   350000  steven.elliott@enron.com                       NaN
# 3           NaN      NaN     bill.cordes@enron.com                       NaN
# 4           NaN  1500000    kevin.hannon@enron.com                       NaN
#
# ...

# %%
# Just a Practice
df.isna().sum()
# Out:
# name                         0
# salary                       0
# to_messages                  0
# deferral_payments            0
# total_payments               0
# loan_advances                0
# bonus                        0
# email_address                0
# restricted_stock_deferred    0
# deferred_income              0
# total_stock_value            0
# expenses                     0
# from_poi_to_this_person      0
# exercised_stock_options      0
# from_messages                0
# other                        0
# from_this_person_to_poi      0
# poi                          0
# long_term_incentive          0
# shared_receipt_with_poi      0
# restricted_stock             0
# director_fees                0
# dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# name                         0
# salary                       0
# to_messages                  0
# deferral_payments            0
# total_payments               0
# loan_advances                0
# bonus                        0
# email_address                0
# restricted_stock_deferred    0
# deferred_income              0
# total_stock_value            0
# expenses                     0
# from_poi_to_this_person      0
# exercised_stock_options      0
# from_messages                0
# other                        0
# from_this_person_to_poi      0
# poi                          0
# long_term_incentive          0
# shared_receipt_with_poi      0
# restricted_stock             0
# director_fees                0
# dtype: int64

# %%
# Replace NaN string objects with np.nan so that we can count total NaN stuff
df.replace(['NaN'], np.nan, inplace=True)
df.isna().sum()
# Out:
# name                           0
# salary                        51
# to_messages                   60
# deferral_payments            107
# total_payments                21
# loan_advances                142
# bonus                         64
# email_address                 35
# restricted_stock_deferred    128
# deferred_income               97
# total_stock_value             20
# expenses                      51
# from_poi_to_this_person       60
# exercised_stock_options       44
# from_messages                 60
# other                         53
# from_this_person_to_poi       60
# poi                            0
# long_term_incentive           80
# shared_receipt_with_poi       60
# restricted_stock              36
# director_fees                129
# dtype: int64

# %%
df.shape[0]
# Out:
# 146

# %%
# How many folks have quantified salary
df.shape[0] - df.salary.isna().sum()
# Out:
# 95

# %%
# similarly how many known email address
df.shape[0] - df.email_address.isna().sum()
# Out:
# 111

# %%
# How many people in the E+F dataset (as it currently exists) have “NaN” for their total payments? 
# What percentage of people in the dataset as a whole is this?

(df.total_payments.isna().sum() / df.shape[0]) * 100
# Out:
# 14.383561643835616

# %%
# Another way of sloving using notna() option
(df.shape[0] - df.total_payments.notna().sum()) / df.shape[0]
# Out:
# 0.14383561643835616

# %%
# How many POIs in the E+F dataset have “NaN” for their total payments? What percentage of POI’s as a whole is this?

# for key, value in df.items():
#     if df.poi.isna() == True:
#         print(df['name'])
    
    
# count = 0
# for key, value in enron_data.items():
#     if value['poi'] == True:
#         count += 1
# count

# for column in df.columns[17:18]:
#     if column == True:
#         print(df.loc[0:, "poi"])

nan = np.nan
len(df.query("(poi == True) and (total_payments == @nan)"))
# Out:
# 0

# %%
# If a machine learning algorithm were to use total_payments as a feature, 
# would you expect it to associate a “NaN” value with POIs or non-POIs?

df.loc[(df['total_payments'].isna()) & (df['poi'] == True)]
# Out:
# Empty DataFrame
# Columns: [name, salary, to_messages, deferral_payments, total_payments, loan_advances, bonus, email_address, restricted_stock_deferred, deferred_income, total_stock_value, expenses, from_poi_to_this_person, exercised_stock_options, from_messages, other, from_this_person_to_poi, poi, long_term_incentive, shared_receipt_with_poi, restricted_stock, director_fees]
# Index: []
#
# [0 rows x 22 columns]

# %%
# If you added in, say, 10 more data points which were all POI’s, and put “NaN” for the total payments for those folks, 
# the numbers you just calculated would change.
# What is the new number of people of the dataset? What is the new number of folks with “NaN” for total payments?
print(df.shape[0] + 10)
print(df['total_payments'].isna().sum() + 10)
# Out:
# 156
# 31

# %%
# What is the new number of POI’s in the dataset? What is the new number of POI’s with NaN for total_payments?
old = df.poi.value_counts()
new = old + 10
new
# Out:
# False    138
# True      28
# Name: poi, dtype: int64

# %%
# nan = np.nan
# if df['poi'] == True and df['total_payments'] == nan:
#     print(df['name'])

# if df['poi'] == True:
#     print('Hello')

# NaN = np.nan
# df.replace(['NaN'], np.nan, inplace=True)
nan = np.NaN
df.loc[df['total_payments'] == nan]
# Out:
# Empty DataFrame
# Columns: [name, salary, to_messages, deferral_payments, total_payments, loan_advances, bonus, email_address, restricted_stock_deferred, deferred_income, total_stock_value, expenses, from_poi_to_this_person, exercised_stock_options, from_messages, other, from_this_person_to_poi, poi, long_term_incentive, shared_receipt_with_poi, restricted_stock, director_fees]
# Index: []
#
# [0 rows x 22 columns]
